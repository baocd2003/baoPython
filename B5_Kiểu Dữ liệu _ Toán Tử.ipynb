# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Kiểu Dữ liệu

# %% [markdown]
# ## Toán Tử

# %% [markdown]
# ### Toán Tử Cộng

# %%
# True -> 1 , False -> 0

# %% [markdown]
# ### Toán tử Trừ

# %% [markdown]
# ### Toán tử nhân

# %% [markdown]
# ### Toán tử chia

# %% [markdown]
# ### Toán tử lấy dư

# %% [markdown]
# ### phép gán

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Lũy Thừa

# %% [markdown]
# ### Toán tử quan hệ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Toán tử logic

# %% [markdown]
# ![image.png](attachment:image.png)
